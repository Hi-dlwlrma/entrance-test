txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4923).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4927).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4930).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4954).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4967).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4972).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4997).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4998).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4999).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5022).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5024).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5029).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5031).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5034).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5051).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5053).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5054).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5062).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5066).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5080).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5084).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5101).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5117).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5160).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5178).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5221).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5222).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5247).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5249).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5256).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5288).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5308).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5361).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5351).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5353).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5365).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5367).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5369).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5370).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5371).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5372).txt
#   inflating: /document_data/document_data/Doi song/DS_NLD_ (5374).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (243).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (346).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5063).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (479).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (516).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (666).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (676).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (696).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (738).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (859).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (935).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5072).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1063).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1235).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1255).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1360).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1433).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1552).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1588).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1674).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1740).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1776).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1991).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2020).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1028).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1415).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2033).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2149).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2380).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2389).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2537).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2546).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2604).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2700).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2755).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2927).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3045).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3063).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3081).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5220).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3199).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3211).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (437).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (480).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (486).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (615).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (651).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (671).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (772).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (778).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (858).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (868).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (918).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1041).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1174).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1201).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1289).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1299).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1355).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1358).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1389).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1414).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1428).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1458).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1460).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1475).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1478).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1480).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1551).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1574).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1586).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1589).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1691).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1705).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1810).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (1878).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2015).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2118).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2231).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2312).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2337).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2364).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2418).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2442).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2508).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2532).txt
#   inflating: /document_data/document_data/Doi song/DS_TT_ (3345).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2573).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2596).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2638).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2681).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2684).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2716).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2760).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2837).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2867).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2870).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2888).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (2908).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3003).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3079).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3082).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3124).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3171).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3283).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (3286).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (253).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (321).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (993).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (632).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (861).txt
#   inflating: /document_data/document_data/Doi song/DS_ VNE_ (926).txt
#   inflating: /document_data/document_data/Doi song/DS_TT_ (3326).txt
#   inflating: /document_data/document_data/Doi song/DS_TT_ (3378).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3473).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3422).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3453).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3458).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3558).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4535).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4560).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4593).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4654).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4664).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4726).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4751).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4943).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4946).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5077).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5104).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5207).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5236).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3615).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3648).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3674).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3680).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3707).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (3710).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4377).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4418).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4514).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4538).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4573).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4580).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4602).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4608).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4679).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4696).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4697).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4715).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4794).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4842).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (4970).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5067).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5096).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5133).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5176).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5185).txt
#   inflating: /document_data/document_data/Doi song/DS_TN_ (5213).txt

# %%
# !/usr/bin/python3
# -*- coding: <encoding name> -*-
# Out:
# Python 3.7.12 (default, Jan 15 2022, 18:48:18)
# [GCC 7.5.0] on linux
# Type "help", "copyright", "credits" or "license" for more information.
# >>> exit()

# %% [markdown]
# https://nguyenvanhieu.vn/phan-loai-van-ban-tieng-viet/

# %%
# !python --version
# Out:
# Python 3.7.12

# %%
# -*- coding: utf-8 -*-

file_name = '/document_data/document_data'

X, y = [], []
classes = ['Chinh tri Xa hoi', 
           'Doi song', 
           'Khoa hoc', 
           'Kinh doanh', 
           'Phap luat', 
           'Suc khoe', 
           'The gioi', 
           'The thao',
           'Van hoa',
           'Vi tinh']

for class_name in classes:
    url = os.path.join(file_name, class_name)
    # print(url)
    for _, _, files in os.walk(url):
        for text in files:
            with open(os.path.join(url, text), encoding='utf-8', errors='ignore') as f:
                X.append(f.read())
            y.append(class_name)

# %%
df = pd.DataFrame({
    "text": X,
    "label": y
})

# %%
df.head()
# Out:
#                                                 text             label
# 0   S
# t l
#  trn
# ng s
# t o ...  Chinh tri Xa hoi
# 1   2.916 t
#
# ng cho qu
# n l...  Chinh tri Xa hoi
# 2  Hm nay 28/3 t
# i TP Plei...  Chinh tri Xa hoi
# 3  Quy trnh 'l
# t xc' c
# a n...  Chinh tri Xa hoi
# 4   Thi cng
# u, b
#  dn ki
# n\...  Chinh tri Xa hoi

# %% [markdown]
# **Train test split data**
# 1. Split dataset into 80% train set and 20% test set
# 2. Convert label to number using LabelEncoding

# %%
train_df, test_df = train_test_split(df, test_size=0.2)

# %%
print(train_df.shape)
print(test_df.shape)
# Out:
# (27007, 2)
# (6752, 2)

# %%
train_df['label'].hist()

# %%
# Encode label
label_encoder = LabelEncoder()
label_encoder.fit(train_df['label'])
print(list(label_encoder.classes_), '\n')
# Out:
# ['Chinh tri Xa hoi', 'Doi song', 'Khoa hoc', 'Kinh doanh', 'Phap luat', 'Suc khoe', 'The gioi', 'The thao', 'Van hoa', 'Vi tinh']

# %%
y_train = label_encoder.transform(train_df['label'])
y_test = label_encoder.transform(test_df['label'])
X_train = train_df['text']
X_test = test_df['text']

# %%
y_test
# Out:
# array([3, 4, 1, ..., 5, 5, 7])

# %% [markdown]
# **Classification**
#
# Use support vector machine algorithm to learn model

# %%
start_time = time.time()
text_clf = Pipeline([('vect', CountVectorizer(ngram_range=(1,1),
                                             max_df=0.8,
                                             max_features=None)), 
                     ('tfidf', TfidfTransformer()),
                     ('clf', SVC(gamma='scale'))
                    ])
text_clf = text_clf.fit(X_train, y_train)
 
train_time = time.time() - start_time
print('Done training SVM in', train_time, 'seconds.')

# Save model
MODEL_PATH = '/content/drive/MyDrive/'
pickle.dump(text_clf, open(os.path.join(MODEL_PATH, "svm.pkl"), 'wb'))
# Out:
# Done training SVM in 26.787238359451294 seconds.

# %% [markdown]
# **Evaluate model**

# %%
model = pickle.load(open(os.path.join(MODEL_PATH,"svm.pkl"), 'rb'))
y_pred = model.predict(X_test)
print('SVM, Accuracy =', np.mean(y_pred == y_test))
# Out:
# SVM, Accuracy = 0.15876777251184834

# %%
nb_model = pickle.load(open(os.path.join(MODEL_PATH,"svm.pkl"), 'rb'))
y_pred = nb_model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=list(label_encoder.classes_)))
# Out:
#                   precision    recall  f1-score   support
#
# Chinh tri Xa hoi       0.00      0.00      0.00      1031
#         Doi song       0.00      0.00      0.00       610
#         Khoa hoc       0.00      0.00      0.00       384
#       Kinh doanh       0.00      0.00      0.00       497
#        Phap luat       0.00      0.00      0.00       789
#         Suc khoe       0.00      0.00      0.00       720
#         The gioi       0.00      0.00      0.00       595
#         The thao       0.16      1.00      0.27      1072
#          Van hoa       0.00      0.00      0.00       583
#          Vi tinh       0.00      0.00      0.00       471
#
#         accuracy                           0.16      6752
#        macro avg       0.02      0.10      0.03      6752
#     weighted avg       0.03      0.16      0.04      6752
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
